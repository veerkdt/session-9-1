# %%
import numpy as np
x=np.arange(0,100)
y=x*2
z=x**2

# %% [markdown]
# Excercise1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# Excercise 2

# %%
fig = plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2 =fig.add_axes([0.2,0.5,.2,.2])

# %%
fig = plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2 =fig.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y)
ax2.plot(x,y)

# %% [markdown]
# Excercise 3

# %%
fig = plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2 =fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# Excercise 4

# %%
plt.subplots(nrows=1,ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000007A8B400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000007AAF9E8>],
#        dtype=object))
